# %%
print("Hello world") #utk baca arahan
print("Hi mior, you too nice today ")
# Out:
# Hello world
# Hi mior, you too nice today

# %%
print("===================================")
print("    SELAMAT DATANG KE KV-TRON      ")
print("===================================")
print("NAMA ROBOT  : KV-TRON")
print("Status      :AKTIF")
